# %% [markdown]
# ref:
# https://github.com/RaRe-Technologies/gensim/blob/920c029ca97f961c8df264672c34936607876694/docs/notebooks/Poincare%20Tutorial.ipynb

# %%
import os
import logging
from tqdm import tqdm_notebook as tqdm
import numpy as np
from nltk.corpus import wordnet as wn
from gensim.models.poincare import PoincareModel, PoincareKeyedVectors, PoincareRelations
logging.basicConfig(level=logging.INFO)

# %%
PoincareModel(train_data=[('node.1', 'node.2'), ('node.2', 'node.3')])
# Out:
# INFO:gensim.models.poincare:Loading relations from train data..
# INFO:gensim.models.poincare:Loaded 2 relations from train data, 3 nodes

# %%
words = wn.words()

# %%
taxi_synets = wn.synsets("dog", pos="n")
taxi_synets
# Out:
# [Synset('dog.n.01'),
#  Synset('frump.n.01'),
#  Synset('dog.n.03'),
#  Synset('cad.n.01'),
#  Synset('frank.n.02'),
#  Synset('pawl.n.01'),
#  Synset('andiron.n.01')]

# %%
taxi_synets[0].hypernyms()
# Out:
# [Synset('canine.n.02'), Synset('domestic_animal.n.01')]

# %%
taxi_synets[0].hypernym_paths()
# Out:
# [[Synset('entity.n.01'),
#   Synset('physical_entity.n.01'),
#   Synset('object.n.01'),
#   Synset('whole.n.02'),
#   Synset('living_thing.n.01'),
#   Synset('organism.n.01'),
#   Synset('animal.n.01'),
#   Synset('chordate.n.01'),
#   Synset('vertebrate.n.01'),
#   Synset('mammal.n.01'),
#   Synset('placental.n.01'),
#   Synset('carnivore.n.01'),
#   Synset('canine.n.02'),
#   Synset('dog.n.01')],
#  [Synset('entity.n.01'),
#   Synset('physical_entity.n.01'),
#   Synset('object.n.01'),
#   Synset('whole.n.02'),
#   Synset('living_thing.n.01'),
#   Synset('organism.n.01'),
#   Synset('animal.n.01'),
#   Synset('domestic_animal.n.01'),
#   Synset('dog.n.01')]]

# %%
nouns = set([])
for word in tqdm(words):
    nouns.update(wn.synsets(word, pos='n'))
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
len(nouns)
# Out:
# 82115

# %%
hypernyms = set([])
for noun in nouns:
    for path in noun.hypernym_paths():
        hypernyms.update( (noun, hypernym) for hypernym in path[1:] if hypernym.pos() == 'n')
with open("hypernyms.tsv", 'w') as f:
        for n1, n2 in hypernyms:
            print(n1.name(), n2.name(), sep="\t", file=f)

# %%
mammals = []
mammal_tree = []
target = wn.synset("mammal.n.01")
for noun in nouns:
    for path in noun.hypernym_paths():
        if target in path:
            pos = path.index(target)
            for i in range(pos, len(path)-1):
                mammals.append((noun, path[i]))
                mammal_tree.append((noun.name(), path[i].name()))
with open("mammals.tsv", 'w') as f:
        for n1, n2 in mammals:
            print(n1.name(), n2.name(), sep="\t", file=f)

# %%
len(mammals)
# Out:
# 6575

# %%
relations = PoincareRelations(file_path="mammals.tsv", delimiter='\t')

# %%
model = PoincareModel(train_data=relations, size=2, burn_in=0)
model.train(epochs=100, print_every=500)
# Out:
# INFO:gensim.models.poincare:Loading relations from train data..
# INFO:gensim.models.poincare:Loaded 6575 relations from train data, 1182 nodes
# INFO:gensim.models.poincare:training model of size 2 with 1 workers on 6575 relations for 100 epochs and 0 burn-in epochs, using lr=0.10000 burn-in lr=0.01000 negative=10
# INFO:gensim.models.poincare:Starting training (100 epochs)----------------------------------------
# INFO:gensim.models.poincare:Training on epoch 1, examples #4990-#5000, loss: 23.85
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.75 s, 6701.37 examples / s
# INFO:gensim.models.poincare:Training on epoch 2, examples #4990-#5000, loss: 22.97
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.72 s, 6908.86 examples / s
# INFO:gensim.models.poincare:Training on epoch 3, examples #4990-#5000, loss: 21.64
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.67 s, 7459.20 examples / s
# INFO:gensim.models.poincare:Training on epoch 4, examples #4990-#5000, loss: 20.37
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.68 s, 7373.95 examples / s
# INFO:gensim.models.poincare:Training on epoch 5, examples #4990-#5000, loss: 19.22
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.66 s, 7628.55 examples / s
# INFO:gensim.models.poincare:Training on epoch 6, examples #4990-#5000, loss: 18.24
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.67 s, 7463.47 examples / s
# INFO:gensim.models.poincare:Training on epoch 7, examples #4990-#5000, loss: 17.46
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.67 s, 7431.64 examples / s
# INFO:gensim.models.poincare:Training on epoch 8, examples #4990-#5000, loss: 16.84
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.65 s, 7699.18 examples / s
# INFO:gensim.models.poincare:Training on epoch 9, examples #4990-#5000, loss: 16.25
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.64 s, 7753.02 examples / s
# INFO:gensim.models.poincare:Training on epoch 10, examples #4990-#5000, loss: 15.75
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.73 s, 6825.56 examples / s
# INFO:gensim.models.poincare:Training on epoch 11, examples #4990-#5000, loss: 15.33
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.72 s, 6958.68 examples / s
# INFO:gensim.models.poincare:Training on epoch 12, examples #4990-#5000, loss: 14.92
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.66 s, 7613.03 examples / s
# INFO:gensim.models.poincare:Training on epoch 13, examples #4990-#5000, loss: 14.49
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.66 s, 7617.48 examples / s
# INFO:gensim.models.poincare:Training on epoch 14, examples #4990-#5000, loss: 14.22
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.67 s, 7460.46 examples / s
# INFO:gensim.models.poincare:Training on epoch 15, examples #4990-#5000, loss: 13.93
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.74 s, 6713.98 examples / s
# INFO:gensim.models.poincare:Training on epoch 16, examples #4990-#5000, loss: 13.75
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.72 s, 6897.41 examples / s
# INFO:gensim.models.poincare:Training on epoch 17, examples #4990-#5000, loss: 13.30
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.67 s, 7451.22 examples / s
# INFO:gensim.models.poincare:Training on epoch 18, examples #4990-#5000, loss: 13.34
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.72 s, 6916.19 examples / s
# INFO:gensim.models.poincare:Training on epoch 19, examples #4990-#5000, loss: 12.99
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.73 s, 6819.14 examples / s
# INFO:gensim.models.poincare:Training on epoch 20, examples #4990-#5000, loss: 12.82
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.76 s, 6588.44 examples / s
# INFO:gensim.models.poincare:Training on epoch 21, examples #4990-#5000, loss: 12.85
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.72 s, 6917.49 examples / s
# INFO:gensim.models.poincare:Training on epoch 22, examples #4990-#5000, loss: 12.61
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.69 s, 7293.46 examples / s
# INFO:gensim.models.poincare:Training on epoch 23, examples #4990-#5000, loss: 12.56
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.64 s, 7758.47 examples / s
# INFO:gensim.models.poincare:Training on epoch 24, examples #4990-#5000, loss: 12.27
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.65 s, 7705.68 examples / s
# INFO:gensim.models.poincare:Training on epoch 25, examples #4990-#5000, loss: 12.16
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.75 s, 6680.05 examples / s
# INFO:gensim.models.poincare:Training on epoch 26, examples #4990-#5000, loss: 12.14
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.66 s, 7599.46 examples / s
# INFO:gensim.models.poincare:Training on epoch 27, examples #4990-#5000, loss: 11.87
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.70 s, 7107.99 examples / s
# INFO:gensim.models.poincare:Training on epoch 28, examples #4990-#5000, loss: 11.76
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.67 s, 7468.07 examples / s
# INFO:gensim.models.poincare:Training on epoch 29, examples #4990-#5000, loss: 11.54
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.76 s, 6619.19 examples / s
# INFO:gensim.models.poincare:Training on epoch 30, examples #4990-#5000, loss: 11.58
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.75 s, 6645.45 examples / s
# INFO:gensim.models.poincare:Training on epoch 31, examples #4990-#5000, loss: 11.52
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.70 s, 7123.35 examples / s
# INFO:gensim.models.poincare:Training on epoch 32, examples #4990-#5000, loss: 11.37
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.77 s, 6465.45 examples / s
# INFO:gensim.models.poincare:Training on epoch 33, examples #4990-#5000, loss: 11.28
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.79 s, 6328.80 examples / s
# INFO:gensim.models.poincare:Training on epoch 34, examples #4990-#5000, loss: 11.12
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.83 s, 5995.85 examples / s
# INFO:gensim.models.poincare:Training on epoch 35, examples #4990-#5000, loss: 11.06
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.79 s, 6336.00 examples / s
# INFO:gensim.models.poincare:Training on epoch 36, examples #4990-#5000, loss: 10.91
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.77 s, 6476.01 examples / s
# INFO:gensim.models.poincare:Training on epoch 37, examples #4990-#5000, loss: 11.00
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.71 s, 7027.80 examples / s
# INFO:gensim.models.poincare:Training on epoch 38, examples #4990-#5000, loss: 10.78
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.79 s, 6309.43 examples / s
# INFO:gensim.models.poincare:Training on epoch 39, examples #4990-#5000, loss: 10.84
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.71 s, 7019.17 examples / s
# INFO:gensim.models.poincare:Training on epoch 40, examples #4990-#5000, loss: 10.76
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.70 s, 7172.33 examples / s
# INFO:gensim.models.poincare:Training on epoch 41, examples #4990-#5000, loss: 10.70
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.80 s, 6229.30 examples / s
# INFO:gensim.models.poincare:Training on epoch 42, examples #4990-#5000, loss: 10.48
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.74 s, 6730.31 examples / s
# INFO:gensim.models.poincare:Training on epoch 43, examples #4990-#5000, loss: 10.37
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.76 s, 6578.37 examples / s
# INFO:gensim.models.poincare:Training on epoch 44, examples #4990-#5000, loss: 10.33
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.70 s, 7108.53 examples / s
# INFO:gensim.models.poincare:Training on epoch 45, examples #4990-#5000, loss: 10.28
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.78 s, 6374.02 examples / s
# INFO:gensim.models.poincare:Training on epoch 46, examples #4990-#5000, loss: 10.03
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.74 s, 6764.79 examples / s
# INFO:gensim.models.poincare:Training on epoch 47, examples #4990-#5000, loss: 10.12
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.68 s, 7385.45 examples / s
# INFO:gensim.models.poincare:Training on epoch 48, examples #4990-#5000, loss: 10.00
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.72 s, 6917.05 examples / s
# INFO:gensim.models.poincare:Training on epoch 49, examples #4990-#5000, loss: 9.97
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.72 s, 6956.67 examples / s
# INFO:gensim.models.poincare:Training on epoch 50, examples #4990-#5000, loss: 9.98
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.80 s, 6268.14 examples / s
# INFO:gensim.models.poincare:Training on epoch 51, examples #4990-#5000, loss: 9.83
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.79 s, 6357.50 examples / s
# INFO:gensim.models.poincare:Training on epoch 52, examples #4990-#5000, loss: 9.68
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.73 s, 6865.96 examples / s
# INFO:gensim.models.poincare:Training on epoch 53, examples #4990-#5000, loss: 9.46
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.81 s, 6191.42 examples / s
# INFO:gensim.models.poincare:Training on epoch 54, examples #4990-#5000, loss: 9.45
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.76 s, 6598.05 examples / s
# INFO:gensim.models.poincare:Training on epoch 55, examples #4990-#5000, loss: 9.64
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.67 s, 7459.70 examples / s
# INFO:gensim.models.poincare:Training on epoch 56, examples #4990-#5000, loss: 9.54
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.70 s, 7188.16 examples / s
# INFO:gensim.models.poincare:Training on epoch 57, examples #4990-#5000, loss: 9.31
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.79 s, 6356.58 examples / s
# INFO:gensim.models.poincare:Training on epoch 58, examples #4990-#5000, loss: 9.34
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.89 s, 5633.53 examples / s
# INFO:gensim.models.poincare:Training on epoch 59, examples #4990-#5000, loss: 9.25
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.80 s, 6230.08 examples / s
# INFO:gensim.models.poincare:Training on epoch 60, examples #4990-#5000, loss: 9.09
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.72 s, 6903.59 examples / s
# INFO:gensim.models.poincare:Training on epoch 61, examples #4990-#5000, loss: 9.28
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.80 s, 6225.20 examples / s
# INFO:gensim.models.poincare:Training on epoch 62, examples #4990-#5000, loss: 8.93
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.79 s, 6301.79 examples / s
# INFO:gensim.models.poincare:Training on epoch 63, examples #4990-#5000, loss: 8.87
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.74 s, 6788.99 examples / s
# INFO:gensim.models.poincare:Training on epoch 64, examples #4990-#5000, loss: 8.98
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.69 s, 7259.43 examples / s
# INFO:gensim.models.poincare:Training on epoch 65, examples #4990-#5000, loss: 8.68
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.75 s, 6674.26 examples / s
# INFO:gensim.models.poincare:Training on epoch 66, examples #4990-#5000, loss: 8.79
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.81 s, 6140.68 examples / s
# INFO:gensim.models.poincare:Training on epoch 67, examples #4990-#5000, loss: 8.70
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.85 s, 5853.95 examples / s
# INFO:gensim.models.poincare:Training on epoch 68, examples #4990-#5000, loss: 8.25
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.74 s, 6756.64 examples / s
# INFO:gensim.models.poincare:Training on epoch 69, examples #4990-#5000, loss: 8.57
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.83 s, 5997.82 examples / s
# INFO:gensim.models.poincare:Training on epoch 70, examples #4990-#5000, loss: 8.64
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.76 s, 6593.78 examples / s
# INFO:gensim.models.poincare:Training on epoch 71, examples #4990-#5000, loss: 8.46
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.83 s, 5992.82 examples / s
# INFO:gensim.models.poincare:Training on epoch 72, examples #4990-#5000, loss: 8.44
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.80 s, 6256.91 examples / s
# INFO:gensim.models.poincare:Training on epoch 73, examples #4990-#5000, loss: 8.43
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.77 s, 6466.88 examples / s
# INFO:gensim.models.poincare:Training on epoch 74, examples #4990-#5000, loss: 8.30
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.78 s, 6398.86 examples / s
# INFO:gensim.models.poincare:Training on epoch 75, examples #4990-#5000, loss: 8.30
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.77 s, 6519.06 examples / s
# INFO:gensim.models.poincare:Training on epoch 76, examples #4990-#5000, loss: 8.11
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.83 s, 5999.15 examples / s
# INFO:gensim.models.poincare:Training on epoch 77, examples #4990-#5000, loss: 8.06
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.79 s, 6337.89 examples / s
# INFO:gensim.models.poincare:Training on epoch 78, examples #4990-#5000, loss: 7.96
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.84 s, 5969.12 examples / s
# INFO:gensim.models.poincare:Training on epoch 79, examples #4990-#5000, loss: 8.02
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.81 s, 6197.45 examples / s
# INFO:gensim.models.poincare:Training on epoch 80, examples #4990-#5000, loss: 7.99
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.71 s, 7086.36 examples / s
# INFO:gensim.models.poincare:Training on epoch 81, examples #4990-#5000, loss: 7.81
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.68 s, 7374.72 examples / s
# INFO:gensim.models.poincare:Training on epoch 82, examples #4990-#5000, loss: 7.61
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.65 s, 7682.20 examples / s
# INFO:gensim.models.poincare:Training on epoch 83, examples #4990-#5000, loss: 7.59
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.67 s, 7441.18 examples / s
# INFO:gensim.models.poincare:Training on epoch 84, examples #4990-#5000, loss: 7.67
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.66 s, 7584.64 examples / s
# INFO:gensim.models.poincare:Training on epoch 85, examples #4990-#5000, loss: 7.63
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.73 s, 6833.36 examples / s
# INFO:gensim.models.poincare:Training on epoch 86, examples #4990-#5000, loss: 7.65
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.73 s, 6892.77 examples / s
# INFO:gensim.models.poincare:Training on epoch 87, examples #4990-#5000, loss: 7.79
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.71 s, 7053.11 examples / s
# INFO:gensim.models.poincare:Training on epoch 88, examples #4990-#5000, loss: 7.57
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.70 s, 7180.20 examples / s
# INFO:gensim.models.poincare:Training on epoch 89, examples #4990-#5000, loss: 7.50
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.80 s, 6214.40 examples / s
# INFO:gensim.models.poincare:Training on epoch 90, examples #4990-#5000, loss: 7.41
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.71 s, 7049.12 examples / s
# INFO:gensim.models.poincare:Training on epoch 91, examples #4990-#5000, loss: 7.27
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.68 s, 7405.96 examples / s
# INFO:gensim.models.poincare:Training on epoch 92, examples #4990-#5000, loss: 7.48
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.75 s, 6631.87 examples / s
# INFO:gensim.models.poincare:Training on epoch 93, examples #4990-#5000, loss: 7.43
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.79 s, 6334.44 examples / s
# INFO:gensim.models.poincare:Training on epoch 94, examples #4990-#5000, loss: 7.14
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.65 s, 7638.91 examples / s
# INFO:gensim.models.poincare:Training on epoch 95, examples #4990-#5000, loss: 7.25
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.66 s, 7550.89 examples / s
# INFO:gensim.models.poincare:Training on epoch 96, examples #4990-#5000, loss: 6.95
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.76 s, 6612.96 examples / s
# INFO:gensim.models.poincare:Training on epoch 97, examples #4990-#5000, loss: 7.21
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.76 s, 6604.55 examples / s
# INFO:gensim.models.poincare:Training on epoch 98, examples #4990-#5000, loss: 6.89
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.76 s, 6591.73 examples / s
# INFO:gensim.models.poincare:Training on epoch 99, examples #4990-#5000, loss: 6.92
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.85 s, 5873.63 examples / s
# INFO:gensim.models.poincare:Training on epoch 100, examples #4990-#5000, loss: 6.86
# INFO:gensim.models.poincare:Time taken for 5000 examples: 0.80 s, 6238.53 examples / s
# INFO:gensim.models.poincare:Training finished

# %%
model.save('./mammal_test_model')
model=PoincareModel.load('./mammal_test_model')
model.kv.save_word2vec_format('./mammal_test_vectors')
PoincareKeyedVectors.load_word2vec_format('./mammal_test_vectors')
# Out:
# INFO:gensim.utils:saving PoincareModel object under ./mammal_test_model, separately None
# INFO:gensim.utils:saved ./mammal_test_model
# INFO:gensim.utils:loading PoincareModel object from ./mammal_test_model
# INFO:gensim.utils:loading kv recursively from ./mammal_test_model.kv.* with mmap=None
# INFO:gensim.utils:loaded ./mammal_test_model
# INFO:gensim.models.keyedvectors:storing 1182x2 projection weights into ./mammal_test_vectors
# INFO:gensim.models.keyedvectors:loading projection weights from ./mammal_test_vectors
# INFO:gensim.models.keyedvectors:loaded (1182, 2) matrix from ./mammal_test_vectors

# %%
model.kv.distance('dog.n.01', 'cat.n.01')
# Out:
# 4.7709195692607285

# %%
model.kv.distance('dog.n.01', 'german_shepherd.n.01')
# Out:
# 6.5684571435202974

# %%
#model.kv.most_similar('electricity.n.01')

# %%
model.kv.most_similar('dog.n.01')
# Out:
# [('canine.n.02', 0.1399973566916916),
#  ('carnivore.n.01', 0.8615759159866268),
#  ('lapdog.n.01', 0.9673234516391055),
#  ('hunting_dog.n.01', 0.9739280759356185),
#  ('basenji.n.01', 1.2982963811506512),
#  ('unguiculata.n.01', 1.4572044659051688),
#  ('cynocephalus_variegatus.n.01', 1.5106376485197455),
#  ('female_mammal.n.01', 1.5403693234649667),
#  ('unguiculate.n.01', 1.5710320351710816),
#  ('plantigrade_mammal.n.01', 1.5715445774974381)]

# %%
import pickle
from plotly.offline import init_notebook_mode, iplot
from gensim.viz.poincare import poincare_2d_visualization, poincare_distance_heatmap

init_notebook_mode(connected=True)

show_node_labels = [
    'mammal.n.01', 'placental.n.01', 'ungulate.n.01', 'carnivore.n.01', 'rodent.n.01',
    'canine.n.02', 'even-toed_ungulate.n.01', 'odd-toed_ungulate.n.01', 'elephant.n.01',
    'rhinoceros.n.01', 'german_shepherd.n.01', 'feline.n.01', 'tiger.n.02', 'homo_sapiens.n.01']
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
figure_title = """
<b>2-D Visualization of model trained on mammals subtree</b><br>
"""
iplot(poincare_2d_visualization(model, mammal_tree, figure_title, show_node_labels=show_node_labels))
# Out:
# <div id="48bf86b9-ad0c-4d9a-9ad6-c20fa15193ab" style="height: 800px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("48bf86b9-ad0c-4d9a-9ad6-c20fa15193ab", [{"type": "scatter", "x": [-0.7865647724864335, 0.07512837495141403, null, -0.7865647724864335, 0.057091671354012545, null, -0.7865647724864335, -0.4588259164361594, null, -0.7865647724864335, -0.6756411165722148, null, 0.6512030744387708, 0.07512837495141403, null, 0.6512030744387708, 0.057091671354012545, null, 0.6512030744387708, 0.5866720339597686, null, 0.6512030744387708, 0.6479678369820508, null, -0.014366002211571801, 0.07512837495141403, null, -0.014366002211571801, 0.057091671354012545, null, -0.014366002211571801, -0.05332505666348586, null, 0.2905491550310025, 0.07512837495141403, null, 0.2905491550310025, 0.057091671354012545, null, 0.2905491550310025, 0.3994954630554691, null, 0.2905491550310025, 0.2913400100905251, null, 0.2905491550310025, 0.3241211991774417, null, 0.2989978707456533, 0.07512837495141403, null, 0.2989978707456533, 0.057091671354012545, null, 0.2989978707456533, 0.37812939896207654, null, 0.2989978707456533, 0.045589219557469265, null, 0.2989978707456533, 0.03934114714268577, null, -0.024688898089320385, 0.07512837495141403, null, -0.024688898089320385, 0.057091671354012545, null, -0.024688898089320385, 0.08645904033379409, null, 0.22319071771880988, 0.07512837495141403, null, 0.22319071771880988, 0.057091671354012545, null, 0.22319071771880988, 0.3994954630554691, null, 0.22319071771880988, 0.2913400100905251, null, 0.9625641586270324, 0.07512837495141403, null, 0.9625641586270324, 0.057091671354012545, null, 0.9625641586270324, 0.37812939896207654, null, 0.9625641586270324, 0.641750127818408, null, 0.9625641586270324, 0.68590904477377, null, 0.9625641586270324, 0.7570434815855392, null, 0.9625641586270324, 0.8408748901790871, null, -0.7360668434882627, 0.07512837495141403, null, -0.7360668434882627, 0.057091671354012545, null, -0.7360668434882627, -0.4588259164361594, null, -0.7360668434882627, -0.6756411165722148, null, 0.058557464741803886, 0.07512837495141403, null, 0.058557464741803886, 0.057091671354012545, null, 0.058557464741803886, 0.37812939896207654, null, 0.058557464741803886, 0.045589219557469265, null, 0.058557464741803886, 0.03934114714268577, null, 0.058557464741803886, -0.01574794706049752, null, -0.6577527141536625, 0.07512837495141403, null, -0.6577527141536625, 0.057091671354012545, null, -0.6577527141536625, -0.4588259164361594, null, -0.6577527141536625, -0.6523252288955862, null, -0.07197577497459554, 0.07512837495141403, null, -0.07197577497459554, 0.057091671354012545, null, -0.07197577497459554, -0.05332505666348586, null, -0.07197577497459554, -0.05921073051518957, null, 0.8607478196640784, 0.07512837495141403, null, 0.8607478196640784, 0.057091671354012545, null, 0.8607478196640784, 0.37812939896207654, null, 0.8607478196640784, 0.641750127818408, null, -0.9594418512252239, 0.07512837495141403, null, -0.9594418512252239, 0.057091671354012545, null, -0.9594418512252239, -0.4588259164361594, null, -0.9594418512252239, -0.6756411165722148, null, -0.9594418512252239, -0.6779711972765572, null, -0.9594418512252239, -0.822371495890655, null, -0.9594418512252239, -0.94880097086354, null, -0.7319064982606256, 0.07512837495141403, null, -0.7319064982606256, 0.057091671354012545, null, -0.7319064982606256, -0.4588259164361594, null, -0.7319064982606256, -0.6756411165722148, null, 0.5523187586512307, 0.07512837495141403, null, 0.5523187586512307, 0.057091671354012545, null, 0.5523187586512307, 0.5866720339597686, null, 0.5523187586512307, 0.5557811942767753, null, 0.5523187586512307, 0.5583138552637312, null, -0.0324898849500555, 0.07512837495141403, null, -0.0324898849500555, 0.057091671354012545, null, -0.0324898849500555, 0.37812939896207654, null, -0.03248 ...
